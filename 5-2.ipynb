# %%
import pandas as pd
wine= pd.read_csv('https://bit.ly/wine_csv_data')
wine.head()
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0
# 3      9.8    1.9  3.16    0.0
# 4      9.4    1.9  3.51    0.0

# %%
data = wine[['alcohol','sugar','pH']]
target = wine[['class']]

# %% [markdown]
# ## 훈련데이터와 검증데이터로 나누기

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(data, target)

# %% [markdown]
# ## 훈련데이터를 sub(훈련세트)와 validation(검증세트)로 나누기

# %%
sub_input, val_input, sub_target, val_target = train_test_split(train_input, train_target)

# %%
sub_input.shape
# Out:
# (3654, 3)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(sub_input, sub_target)
print(dt.score(sub_input, sub_target))
print(dt.score(val_input, val_target))
# Out:
# 0.9989053092501369
# 0.8513957307060755

# %%
print(dt.score(test_input, test_target))
# Out:
# 0.8547692307692307

# %% [markdown]
# # **교차검증**

# %%
from sklearn.model_selection import cross_validate

scores = cross_validate(dt, train_input, train_target)
print(scores)
# Out:
# {'fit_time': array([0.00688434, 0.00623298, 0.00550842, 0.00566411, 0.00537062]), 'score_time': array([0.00256348, 0.00196648, 0.0020659 , 0.0018692 , 0.00206828]), 'test_score': array([0.85435897, 0.86769231, 0.84804928, 0.8449692 , 0.86344969])}

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'min_impurity_decrease' : [0.0001, 0.0002, 0.0003, 0.0004]
}

# %%
gs = GridSearchCV(dt, params, n_jobs= -1)

# %%
gs.fit(train_input, train_target)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'min_impurity_decrease': [0.0001, 0.0002, 0.0003,
#                                                    0.0004]})

# %%
gs.best_estimator_
# Out:
# DecisionTreeClassifier(min_impurity_decrease=0.0002)

# %%
# params = {
    'min_impurity_decrease' : np.arange(0.0001, 0.001, 0.01),
    'max_depth' : range(5, 20, 1),
    'min_sample_split' : range(2, 100, 10)
}
# Out:
#   Cell In[42], line 2
#     'min_impurity_decrease' : np.arange(0.0001, 0.001, 0.01),
#     ^
# IndentationError: unexpected indent
